# %% [markdown]
# <a href="https://colab.research.google.com/github/azulsofia0498-cyber/Challenge3-DataScience/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("telecomx_clean.csv")

# %%
df.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  \
# 0  0002-ORFBO    0.0  Female              0        1           1
# 1  0003-MKNFE    0.0    Male              0        0           0
# 2  0004-TLHLJ    1.0    Male              0        0           0
# 3  0011-IGKFF    1.0    Male              1        1           0
# 4  0013-EXCHZ    1.0  Female              1        1           0
#
#    Antiguedad_Meses  PhoneService MultipleLines InternetService  ...  \
# 0                 9             1            No             DSL  ...
# 1                 9             1           Yes             DSL  ...
# 2                 4             1            No     Fiber optic  ...
# 3                13             1            No     Fiber optic  ...
# 4                 3             1            No     Fiber optic  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            1            1                0
# ...

# %%
df = df.drop(columns=["customerID"])

df.head()
# Out:
#    Churn  gender  SeniorCitizen  Partner  Dependents  Antiguedad_Meses  \
# 0    0.0  Female              0        1           1                 9
# 1    0.0    Male              0        0           0                 9
# 2    1.0    Male              0        0           0                 4
# 3    1.0    Male              1        1           0                13
# 4    1.0  Female              1        1           0                 3
#
#    PhoneService MultipleLines InternetService  OnlineSecurity  ...  \
# 0             1            No             DSL               0  ...
# 1             1           Yes             DSL               0  ...
# 2             1            No     Fiber optic               0  ...
# 3             1            No     Fiber optic               0  ...
# 4             1            No     Fiber optic               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            1            1                0
# ...

# %%
df.columns
# Out:
# Index(['Churn', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Antiguedad_Meses', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Tipo_Contrato', 'PaperlessBilling',
#        'Metodo_Pago', 'Cargo_Mensual', 'Cargo_Total', 'Cuentas_Diarias'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

df_encoded.head()
# Out:
#    Churn  SeniorCitizen  Partner  Dependents  Antiguedad_Meses  PhoneService  \
# 0    0.0              0        1           1                 9             1
# 1    0.0              0        0           0                 9             1
# 2    1.0              0        0           0                 4             1
# 3    1.0              1        1           0                13             1
# 4    1.0              1        1           0                 3             1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  ...  \
# 0               0             1                 0            1  ...
# 1               0             0                 0            0  ...
# 2               0             0                 1            0  ...
# 3               0             1                 1            0  ...
# 4               0             0                 0            1  ...
#
#    Cuentas_Diarias  gender_Male  MultipleLines_Yes  \
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0.0    5174
# 1.0    1869
# Name: count, dtype: int64

# %%
sns.countplot(x="Churn", data=df)

plt.title("Distribución de Cancelación de Clientes")
plt.show()

# %%
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# 0.0    73.463013
# 1.0    26.536987
# Name: proportion, dtype: float64

# %%
df_encoded.columns
# Out:
# Index(['Churn', 'SeniorCitizen', 'Partner', 'Dependents', 'Antiguedad_Meses',
#        'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling',
#        'Cargo_Mensual', 'Cargo_Total', 'Cuentas_Diarias', 'gender_Male',
#        'MultipleLines_Yes', 'InternetService_Fiber optic',
#        'InternetService_No', 'Tipo_Contrato_One year',
#        'Tipo_Contrato_Two year', 'Metodo_Pago_Credit card (automatic)',
#        'Metodo_Pago_Electronic check', 'Metodo_Pago_Mailed check'],
#       dtype='object')

# %%
churn_rate = df['Churn'].value_counts(normalize=True)

print("Clientes activos:", churn_rate[0.0] * 100, "%")
print("Clientes que cancelaron:", churn_rate[1.0] * 100, "%")
# Out:
# Clientes activos: 73.4630129206304 %
# Clientes que cancelaron: 26.536987079369588 %

# %%
df['Churn'].isna().sum()
# Out:
# np.int64(224)

# %%
df = df.dropna(subset=['Churn'])

# %% [markdown]
# Separamos variables

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

X_res, y_res = ros.fit_resample(X, y)

print(y_res.value_counts())
# Out:
# Churn
# 0.0    5174
# 1.0    5174
# Name: count, dtype: int64

# %% [markdown]
# Correclación

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64'])
numerical_cols.head()
# Out:
#    Churn  SeniorCitizen  Partner  Dependents  Antiguedad_Meses  PhoneService  \
# 0    0.0              0        1           1                 9             1
# 1    0.0              0        0           0                 9             1
# 2    1.0              0        0           0                 4             1
# 3    1.0              1        1           0                13             1
# 4    1.0              1        1           0                 3             1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 0               0             1                 0            1            1
# 1               0             0                 0            0            0
# 2               0             0                 1            0            0
# 3               0             1                 1            0            1
# 4               0             0                 0            1            1
#
# ...

# %%
corr = numerical_cols.corr()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Matriz de correlación de variables numéricas")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="Churn", y="Antiguedad_Meses", data=df)

plt.title("Antigüedad del cliente vs Cancelación")
plt.xlabel("Cancelación")
plt.ylabel("Antigüedad (Meses)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="Churn", y="Cargo_Total", data=df)

plt.title("Cargo total vs Cancelación")
plt.xlabel("Cancelación")
plt.ylabel("Cargo Total")

plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,   # 30% para prueba
    random_state=42, # para reproducibilidad
    stratify=y       # mantiene la proporción de clases
)

# %%
print("Tamaño X_train:", X_train.shape)
print("Tamaño X_test:", X_test.shape)
print("Tamaño y_train:", y_train.shape)
print("Tamaño y_test:", y_test.shape)
# Out:
# Tamaño X_train: (4930, 20)
# Tamaño X_test: (2113, 20)
# Tamaño y_train: (4930,)
# Tamaño y_test: (2113,)

# %%
X_train.select_dtypes(include=['object']).columns
# Out:
# Index(['gender', 'MultipleLines', 'InternetService', 'Tipo_Contrato',
#        'Metodo_Pago'],
#       dtype='object')

# %%
X_train = X_train.drop(columns=['customerID'], errors='ignore')
X_test = X_test.drop(columns=['customerID'], errors='ignore')

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# Asegurar que X_test tenga las mismas columnas que X_train
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Modelo 1: Regresión Logistica

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

logreg = LogisticRegression(max_iter=1000, random_state=42)
logreg.fit(X_train_scaled, y_train)

y_pred_log = logreg.predict(X_test_scaled)

print("Reporte de Regresión Logística:\n", classification_report(y_test, y_pred_log))
# Out:
# Reporte de Regresión Logística:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.89      0.87      1552
#          1.0       0.64      0.55      0.59       561
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.72      0.73      2113
# weighted avg       0.79      0.80      0.79      2113

# %% [markdown]
# Modelo 2: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Reporte de Random Forest:\n", classification_report(y_test, y_pred_rf))
# Out:
# Reporte de Random Forest:
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.89      0.86      1552
#          1.0       0.62      0.49      0.55       561
#
#     accuracy                           0.78      2113
#    macro avg       0.72      0.69      0.70      2113
# weighted avg       0.77      0.78      0.77      2113

# %% [markdown]
# Importar Metricas

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
# Predicciones ya generadas: y_pred_log
accuracy_log = accuracy_score(y_test, y_pred_log)
precision_log = precision_score(y_test, y_pred_log)
recall_log = recall_score(y_test, y_pred_log)
f1_log = f1_score(y_test, y_pred_log)
cm_log = confusion_matrix(y_test, y_pred_log)

print("=== Regresión Logística ===")
print("Accuracy:", round(accuracy_log, 4))
print("Precision:", round(precision_log, 4))
print("Recall:", round(recall_log, 4))
print("F1-score:", round(f1_log, 4))
print("Matriz de confusión:\n", cm_log)
# Out:
# === Regresión Logística ===
# Accuracy: 0.7984
# Precision: 0.6415
# Recall: 0.5455
# F1-score: 0.5896
# Matriz de confusión:
#  [[1381  171]
#  [ 255  306]]

# %%
# Predicciones ya generadas: y_pred_rf
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
cm_rf = confusion_matrix(y_test, y_pred_rf)

print("=== Random Forest ===")
print("Accuracy:", round(accuracy_rf, 4))
print("Precision:", round(precision_rf, 4))
print("Recall:", round(recall_rf, 4))
print("F1-score:", round(f1_rf, 4))
print("Matriz de confusión:\n", cm_rf)
# Out:
# === Random Forest ===
# Accuracy: 0.7832
# Precision: 0.6152
# Recall: 0.4902
# F1-score: 0.5456
# Matriz de confusión:
#  [[1380  172]
#  [ 286  275]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

# Regresión Logística
plt.subplot(1,2,1)
sns.heatmap(cm_log, annot=True, fmt='d', cmap='Blues')
plt.title("Matriz de Confusión - Regresión Logística")
plt.xlabel("Predicted")
plt.ylabel("Actual")

# Random Forest
plt.subplot(1,2,2)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Greens')
plt.title("Matriz de Confusión - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %% [markdown]
# El proyecto tuvo como objetivo desarrollar un modelo para analizar y predecir la cancelación de clientes (churn) en la empresa Telecom X. Para ello se realizó un análisis exploratorio de datos, preparación de la información y construcción de modelos de machine learning con el fin de identificar los factores que influyen en la decisión de los clientes de abandonar el servicio.
#
# Se utilizó el dataset telecomx_clean.csv, que contiene las variables relevantes ya corregidas y estandarizadas. Se eliminaron columnas sin valor analítico, como customerID, y se transformaron las variables categóricas mediante one-hot encoding. Además, se verificó la variable objetivo Churn y se eliminaron valores faltantes para asegurar la calidad de los datos.
#
# El análisis mostró que el 73 % de los clientes permanecen activos y el 27 % cancelaron, lo que indica un desbalance moderado de clases. Las exploraciones y la matriz de correlación revelaron que los clientes con menor antigüedad, contratos más cortos y valores extremos en cargos mensuales o totales presentan mayor probabilidad de cancelar el servicio. Visualizaciones como boxplots y scatter plots confirmaron estas tendencias
